# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('avocado.csv')
df=df.set_index("Sr.No")
df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# Sr.No
# 0      27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1      20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2      13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3      06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4      29-11-2015          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 7      04-02-2018          1.63      17074.83  2046.96    1529.20    0.00
# 8      28-01-2018          1.71      13888.04  1191.70    3431.50    0.00
# 9      21-01-2018          1.87      13766.76  1191.92    2452.79  727.94
# 10     14-01-2018          1.93      16205.22  1527.63    2981.04  727.01
# 11     07-01-2018          1.62      17489.58  2894.77    2356.13  224.53
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df=pd.DataFrame(np.random.rand(10,6),columns=['AveragePrice', 'Total Volume','Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags'])
print(df)
df.plot.bar()
# Out:
#    AveragePrice  Total Volume  Total Bags  Small Bags  Large Bags  XLarge Bags
# 0      0.320398      0.022432    0.658429    0.011077    0.026748     0.310686
# 1      0.538252      0.626628    0.503664    0.116430    0.205640     0.550724
# 2      0.238115      0.872516    0.498877    0.408224    0.076738     0.931079
# 3      0.213941      0.627403    0.597214    0.870506    0.152744     0.240875
# 4      0.684298      0.858737    0.959127    0.289376    0.360289     0.836259
# 5      0.917491      0.784792    0.888075    0.124880    0.320120     0.899859
# 6      0.555570      0.033107    0.226129    0.238575    0.037206     0.740165
# 7      0.861852      0.542740    0.507487    0.781361    0.472279     0.314017
# 8      0.335291      0.284374    0.743452    0.877477    0.011966     0.830995
# 9      0.049258      0.066509    0.677275    0.701797    0.058224     0.547204
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.rand(10,3),columns=['4046','4225','4770'])
print(df)
df.plot.bar()
# Out:
#        4046      4225      4770
# 0  0.046149  0.584629  0.894264
# 1  0.336847  0.743930  0.519086
# 2  0.472520  0.474418  0.622936
# 3  0.603982  0.102039  0.157173
# 4  0.488838  0.337551  0.372076
# 5  0.422015  0.829417  0.119949
# 6  0.965194  0.447210  0.125736
# 7  0.622630  0.034550  0.747987
# 8  0.533015  0.147124  0.507970
# 9  0.474495  0.253160  0.339435
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume  Total Bags  Small Bags  Large Bags  \
# count     10.000000     10.000000   10.000000   10.000000   10.000000
# mean       0.471447      0.471924    0.625973    0.441970    0.172196
# std        0.288399      0.342417    0.211615    0.335657    0.161919
# min        0.049258      0.022432    0.226129    0.011077    0.011966
# 25%        0.258685      0.120975    0.504620    0.153304    0.042460
# 50%        0.436771      0.584684    0.627821    0.348800    0.114741
# 75%        0.652116      0.745445    0.726907    0.761470    0.291500
# max        0.917491      0.872516    0.959127    0.877477    0.472279
#
#        XLarge Bags
# count    10.000000
# mean      0.620186
# std       0.263302
# min       0.240875
# 25%       0.372314
# 50%       0.645445
# 75%       0.834943
# max       0.931079

# %%
df['AveragePrice'].min()
# Out:
# 0.04925847407119477

# %%
df['AveragePrice'].max()
# Out:
# 0.917491267006342

# %%
df.boxplot(figsize=[20,8])
plt.show()

# %%
plt.hist(df['Total Volume'],bins=10)
plt.title('Total Volume Histogram')
plt.show()

# %%
plt.hist(df['Total Bags'],bins=10)
plt.title('Total Bags Histogram')
plt.show()

# %%
df.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=1,figsize=(18,12))
plt.show()

# %%
df.iloc[:,0:15]
sns.stripplot(x="region",y="Total Volume",data=df)
plt.title('Region graph')
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.iloc[:,0:50]
plt.xticks(rotation=90,fontsize=10)
sns.stripplot(x="region",y="Total Volume",data=df)
plt.title('Region Volume',fontsize=10,fontweight="bold")
plt.show()
